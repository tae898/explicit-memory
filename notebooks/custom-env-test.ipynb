# %%
import numpy as np

from gym.spaces import Space
from gym import logger
from gym.spaces import Box

class MyBox(Space):
    """
    A (possibly unbounded) box in R^n. Specifically, a Box represents the
    Cartesian product of n closed intervals. Each interval has the form of one
    of [a, b], (-oo, b], [a, oo), or (-oo, oo).

    There are two common use cases:

    * Identical bound for each dimension::
        >>> Box(low=-1.0, high=2.0, shape=(3, 4), dtype=np.float32)
        Box(3, 4)

    * Independent bound for each dimension::
        >>> Box(low=np.array([-1.0, -2.0]), high=np.array([2.0, 4.0]), dtype=np.float32)
        Box(2,)

    """
    def __init__(self, low, high, shape=None, dtype=np.float32):
        assert dtype is not None, 'dtype must be explicitly provided. '
        self.dtype = np.dtype(dtype)

        # determine shape if it isn't provided directly
        if shape is not None:
            shape = tuple(shape)
            assert np.isscalar(low) or low.shape == shape, "low.shape doesn't match provided shape"
            assert np.isscalar(high) or high.shape == shape, "high.shape doesn't match provided shape"
        elif not np.isscalar(low):
            shape = low.shape
            assert np.isscalar(high) or high.shape == shape, "high.shape doesn't match low.shape"
        elif not np.isscalar(high):
            shape = high.shape
            assert np.isscalar(low) or low.shape == shape, "low.shape doesn't match high.shape"
        else:
            raise ValueError("shape must be provided or inferred from the shapes of low or high")

        if np.isscalar(low):
            low = np.full(shape, low, dtype=dtype)

        if np.isscalar(high):
            high = np.full(shape, high, dtype=dtype)

        self.shape = shape
        self.low = low
        self.high = high

        def _get_precision(dtype):
            if np.issubdtype(dtype, np.floating):
                return np.finfo(dtype).precision
            else:
                return np.inf
        low_precision = _get_precision(self.low.dtype)
        high_precision = _get_precision(self.high.dtype)
        dtype_precision = _get_precision(self.dtype)
        if min(low_precision, high_precision) > dtype_precision:
            logger.warn("Box bound precision lowered by casting to {}".format(self.dtype))
        self.low = self.low.astype(self.dtype)
        self.high = self.high.astype(self.dtype)

        # Boolean arrays which indicate the interval type for each coordinate
        self.bounded_below = -np.inf < self.low
        self.bounded_above = np.inf > self.high

        super().__init__(self.shape, self.dtype)

    def is_bounded(self, manner="both"):
        below = np.all(self.bounded_below)
        above = np.all(self.bounded_above)
        if manner == "both":
            return below and above
        elif manner == "below":
            return below
        elif manner == "above":
            return above
        else:
            raise ValueError("manner is not in {'below', 'above', 'both'}")

    def sample(self):
        """
        Generates a single random sample inside of the Box.

        In creating a sample of the box, each coordinate is sampled according to
        the form of the interval:

        * [a, b] : uniform distribution
        * [a, oo) : shifted exponential distribution
        * (-oo, b] : shifted negative exponential distribution
        * (-oo, oo) : normal distribution
        """
        high = self.high if self.dtype.kind == 'f' \
                else self.high.astype('int64') + 1
        sample = np.empty(self.shape)

        # Masking arrays which classify the coordinates according to interval
        # type
        unbounded   = ~self.bounded_below & ~self.bounded_above
        upp_bounded = ~self.bounded_below &  self.bounded_above
        low_bounded =  self.bounded_below & ~self.bounded_above
        bounded     =  self.bounded_below &  self.bounded_above


        # Vectorized sampling by interval type
        sample[unbounded] = self.np_random.normal(
                size=unbounded[unbounded].shape)

        sample[low_bounded] = self.np_random.exponential(
            size=low_bounded[low_bounded].shape) + self.low[low_bounded]

        sample[upp_bounded] = -self.np_random.exponential(
            size=upp_bounded[upp_bounded].shape) + self.high[upp_bounded]

        sample[bounded] = self.np_random.uniform(low=self.low[bounded],
                                            high=high[bounded],
                                            size=bounded[bounded].shape)
        if self.dtype.kind == 'i':
            sample = np.floor(sample)

        return sample.astype(self.dtype)

    def contains(self, x):
        if isinstance(x, list):
            x = np.array(x)  # Promote list to array for contains check
        return x.shape == self.shape and np.all(x >= self.low) and np.all(x <= self.high)

    def to_jsonable(self, sample_n):
        return np.array(sample_n).tolist()

    def from_jsonable(self, sample_n):
        return [np.asarray(sample) for sample in sample_n]

    def __repr__(self):
        return "Box({}, {}, {}, {})".format(self.low.min(), self.high.max(), self.shape, self.dtype)

    def __eq__(self, other):
        return isinstance(other, Box) and (self.shape == other.shape) and np.allclose(self.low, other.low) and np.allclose(self.high, other.high)

# %%
import numpy as np
import gym
from gym import spaces


class GoLeftEnv(gym.Env):
    """
    Custom Environment that follows gym interface.
    This is a simple env where the agent must learn to go always left.
    """

    # Because of google colab, we cannot implement the GUI ('human' render mode)
    metadata = {"render.modes": ["console"]}
    # Define constants for clearer code
    LEFT = 0
    RIGHT = 1

    def __init__(self, grid_size=10):
        super(GoLeftEnv, self).__init__()

        # Size of the 1D-grid
        self.grid_size = grid_size
        # Initialize the agent at the right of the grid
        self.agent_pos = grid_size - 1

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions, we have two: left and right
        n_actions = 2
        self.action_space = spaces.Discrete(n_actions)
        # The observation will be the coordinate of the agent
        # this can be described both by Discrete and Box space
        self.observation_space = MyBox(
            low=0, high=self.grid_size, shape=(1,), dtype=np.float32
        )

    def reset(self):
        """
        Important: the observation must be a numpy array
        :return: (np.array)
        """
        # Initialize the agent at the right of the grid
        self.agent_pos = self.grid_size - 1
        # here we convert to float32 to make it more general (in case we want to use continuous actions)
        return np.array([self.agent_pos]).astype(np.float32)

    def step(self, action):
        if action == self.LEFT:
            self.agent_pos -= 1
        elif action == self.RIGHT:
            self.agent_pos += 1
        else:
            raise ValueError(
                "Received invalid action={} which is not part of the action space".format(
                    action
                )
            )

        # Account for the boundaries of the grid
        self.agent_pos = np.clip(self.agent_pos, 0, self.grid_size)

        # Are we at the left of the grid?
        done = bool(self.agent_pos == 0)

        # Null reward everywhere except when reaching the goal (left of the grid)
        reward = 1 if self.agent_pos == 0 else 0

        # Optionally we can pass additional info, we are not using that for now
        info = {}

        return np.array([self.agent_pos]).astype(np.float32), reward, done, info

    def render(self, mode="console"):
        if mode != "console":
            raise NotImplementedError()
        # agent is represented as a cross, rest as a dot
        print("." * self.agent_pos, end="")
        print("x", end="")
        print("." * (self.grid_size - self.agent_pos))

    def close(self):
        pass

# %%
import os
from collections import OrderedDict, deque, namedtuple
from typing import List, Tuple

import gym
import numpy as np
import torch
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.utilities import DistributedType
from torch import Tensor, nn
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset

PATH_DATASETS = os.environ.get("PATH_DATASETS", ".")
AVAIL_GPUS = min(1, torch.cuda.device_count())

# %%
class DQN(nn.Module):
    """Simple MLP network."""

    def __init__(self, obs_size: int, n_actions: int, hidden_size: int = 128):
        """
        Args:
            obs_size: observation/state size of the environment
            n_actions: number of discrete actions available in the environment
            hidden_size: size of hidden layers
        """
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
        )

    def forward(self, x):
        return self.net(x.float())

# %%
# Named tuple for storing experience steps gathered in training
Experience = namedtuple(
    "Experience",
    field_names=["state", "action", "reward", "done", "new_state"],
)

# %%
class ReplayBuffer:
    """Replay Buffer for storing past experiences allowing the agent to learn from them.

    Args:
        capacity: size of the buffer
    """

    def __init__(self, capacity: int) -> None:
        self.buffer = deque(maxlen=capacity)

    def __len__(self) -> None:
        return len(self.buffer)

    def append(self, experience: Experience) -> None:
        """Add experience to the buffer.

        Args:
            experience: tuple (state, action, reward, done, new_state)
        """
        self.buffer.append(experience)

    def sample(self, batch_size: int) -> Tuple:
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*(self.buffer[idx] for idx in indices))

        return (
            np.array(states),
            np.array(actions),
            np.array(rewards, dtype=np.float32),
            np.array(dones, dtype=np.bool),
            np.array(next_states),
        )

# %%
class RLDataset(IterableDataset):
    """Iterable Dataset containing the ExperienceBuffer which will be updated with new experiences during training.

    Args:
        buffer: replay buffer
        sample_size: number of experiences to sample at a time
    """

    def __init__(self, buffer: ReplayBuffer, sample_size: int = 200) -> None:
        self.buffer = buffer
        self.sample_size = sample_size

    def __iter__(self) -> Tuple:
        states, actions, rewards, dones, new_states = self.buffer.sample(self.sample_size)
        for i in range(len(dones)):
            yield states[i], actions[i], rewards[i], dones[i], new_states[i]

# %%
class Agent:
    """Base Agent class handeling the interaction with the environment."""

    def __init__(self, env: gym.Env, replay_buffer: ReplayBuffer) -> None:
        """
        Args:
            env: training environment
            replay_buffer: replay buffer storing experiences
        """
        self.env = env
        self.replay_buffer = replay_buffer
        self.reset()
        self.state = self.env.reset()

    def reset(self) -> None:
        """Resents the environment and updates the state."""
        self.state = self.env.reset()

    def get_action(self, net: nn.Module, epsilon: float, device: str) -> int:
        """Using the given network, decide what action to carry out using an epsilon-greedy policy.

        Args:
            net: DQN network
            epsilon: value to determine likelihood of taking a random action
            device: current device

        Returns:
            action
        """
        if np.random.random() < epsilon:
            action = self.env.action_space.sample()
        else:
            state = torch.tensor([self.state])

            if device not in ["cpu"]:
                state = state.cuda(device)

            q_values = net(state)
            _, action = torch.max(q_values, dim=1)
            action = int(action.item())

        return action

    @torch.no_grad()
    def play_step(
        self,
        net: nn.Module,
        epsilon: float = 0.0,
        device: str = "cpu",
    ) -> Tuple[float, bool]:
        """Carries out a single interaction step between the agent and the environment.

        Args:
            net: DQN network
            epsilon: value to determine likelihood of taking a random action
            device: current device

        Returns:
            reward, done
        """

        action = self.get_action(net, epsilon, device)

        # do step in the environment
        new_state, reward, done, _ = self.env.step(action)

        exp = Experience(self.state, action, reward, done, new_state)

        self.replay_buffer.append(exp)

        self.state = new_state
        if done:
            self.reset()
        return reward, done

# %%
class DQNLightning(LightningModule):
    """Basic DQN Model."""

    def __init__(
        self,
        batch_size: int = 16,
        lr: float = 1e-2,
        env: str = "CartPole-v0",
        gamma: float = 0.99,
        sync_rate: int = 10,
        replay_size: int = 1000,
        warm_start_size: int = 1000,
        eps_last_frame: int = 1000,
        eps_start: float = 1.0,
        eps_end: float = 0.01,
        episode_length: int = 200,
        warm_start_steps: int = 1000,
    ) -> None:
        """
        Args:
            batch_size: size of the batches")
            lr: learning rate
            env: gym environment tag
            gamma: discount factor
            sync_rate: how many frames do we update the target network
            replay_size: capacity of the replay buffer
            warm_start_size: how many samples do we use to fill our buffer at the start of training
            eps_last_frame: what frame should epsilon stop decaying
            eps_start: starting value of epsilon
            eps_end: final value of epsilon
            episode_length: max length of an episode
            warm_start_steps: max episode reward in the environment
        """
        super().__init__()
        self.save_hyperparameters()

        # self.env = gym.make(self.hparams.env)
        self.env = GoLeftEnv()
        obs_size = self.env.observation_space.shape[0]
        n_actions = self.env.action_space.n

        self.net = DQN(obs_size, n_actions)
        self.target_net = DQN(obs_size, n_actions)

        self.buffer = ReplayBuffer(self.hparams.replay_size)
        self.agent = Agent(self.env, self.buffer)
        self.total_reward = 0
        self.episode_reward = 0
        self.populate(self.hparams.warm_start_steps)

    def populate(self, steps: int = 1000) -> None:
        """Carries out several random steps through the environment to initially fill up the replay buffer with
        experiences.

        Args:
            steps: number of random steps to populate the buffer with
        """
        for i in range(steps):
            self.agent.play_step(self.net, epsilon=1.0)

    def forward(self, x: Tensor) -> Tensor:
        """Passes in a state x through the network and gets the q_values of each action as an output.

        Args:
            x: environment state

        Returns:
            q values
        """
        output = self.net(x)
        return output

    def dqn_mse_loss(self, batch: Tuple[Tensor, Tensor]) -> Tensor:
        """Calculates the mse loss using a mini batch from the replay buffer.

        Args:
            batch: current mini batch of replay data

        Returns:
            loss
        """
        states, actions, rewards, dones, next_states = batch

        state_action_values = (
            self.net(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)
        )

        with torch.no_grad():
            next_state_values = self.target_net(next_states).max(1)[0]
            next_state_values[dones] = 0.0
            next_state_values = next_state_values.detach()

        expected_state_action_values = next_state_values * self.hparams.gamma + rewards

        return nn.MSELoss()(state_action_values, expected_state_action_values)

    def training_step(self, batch: Tuple[Tensor, Tensor], nb_batch) -> OrderedDict:
        """Carries out a single step through the environment to update the replay buffer.
        Then calculates loss based on the minibatch recieved.

        Args
        ----
        batch: current mini batch of replay data
        nb_batch: batch number

        Returns
        -------
        Training loss and log metrics

        """
        device = self.get_device(batch)
        epsilon = max(
            self.hparams.eps_end,
            self.hparams.eps_start - self.global_step + 1 / self.hparams.eps_last_frame,
        )

        # step through environment with agent
        reward, done = self.agent.play_step(self.net, epsilon, device)
        self.episode_reward += reward

        # calculates training loss
        loss = self.dqn_mse_loss(batch)

        if self.trainer._distrib_type in {DistributedType.DP, DistributedType.DDP2}:
            loss = loss.unsqueeze(0)

        if done:
            self.total_reward = self.episode_reward
            self.episode_reward = 0

        # Soft update of target network
        if self.global_step % self.hparams.sync_rate == 0:
            self.target_net.load_state_dict(self.net.state_dict())

        log = {
            "total_reward": torch.tensor(self.total_reward).to(device),
            "reward": torch.tensor(reward).to(device),
            "train_loss": loss,
        }
        print(log)
        status = {
            "steps": torch.tensor(self.global_step).to(device),
            "total_reward": torch.tensor(self.total_reward).to(device),
        }

        return OrderedDict({"loss": loss, "log": log, "progress_bar": status})

    def configure_optimizers(self) -> List[Optimizer]:
        """Initialize Adam optimizer."""
        optimizer = Adam(self.net.parameters(), lr=self.hparams.lr)
        return [optimizer]

    def __dataloader(self) -> DataLoader:
        """Initialize the Replay Buffer dataset used for retrieving experiences."""
        dataset = RLDataset(self.buffer, self.hparams.episode_length)
        dataloader = DataLoader(
            dataset=dataset,
            batch_size=self.hparams.batch_size,
        )
        return dataloader

    def train_dataloader(self) -> DataLoader:
        """Get train loader."""
        return self.__dataloader()

    def get_device(self, batch) -> str:
        """Retrieve device currently being used by minibatch."""
        return batch[0].device.index if self.on_gpu else "cpu"

# %%
model = DQNLightning()

trainer = Trainer(
    gpus=AVAIL_GPUS,
    max_epochs=200,
    val_check_interval=100,
)

trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type | Params
# ------------------------------------
# 0 | net        | DQN  | 514
# 1 | target_net | DQN  | 514
# ------------------------------------
# 1.0 K     Trainable params
# 0         Non-trainable params
# 1.0 K     Total params
# 0.004     Total estimated model params size (MB)
# Epoch 0: : 0it [00:00, 2600.31it/s]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(16.6512, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 1it [00:00, 195.91it/s, loss=16.7, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(2.8564, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 2it [00:00, 182.86it/s, loss=9.75, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.8709, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 3it [00:00, 161.08it/s, loss=7.13, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(3.4042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 4it [00:00, 154.02it/s, loss=6.2, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.7338, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 5it [00:00, 152.37it/s, loss=5.3, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.7127, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 6it [00:00, 149.38it/s, loss=4.7, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.8564, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 7it [00:00, 147.50it/s, loss=4.16, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.6311, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 8it [00:00, 150.80it/s, loss=3.71, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.1628, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 9it [00:00, 150.64it/s, loss=3.43, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.8809, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 10it [00:00, 149.93it/s, loss=3.18, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.7813, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 11it [00:00, 151.08it/s, loss=2.96, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.4866, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 12it [00:00, 150.53it/s, loss=2.75, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.0735, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 0it [00:00, 1964.55it/s, loss=2.62, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.5154, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 1it [00:00, 190.26it/s, loss=2.47, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.7309, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 2it [00:00, 144.91it/s, loss=2.36, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2226, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 3it [00:00, 133.49it/s, loss=2.22, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0684, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 4it [00:00, 129.05it/s, loss=2.1, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1408, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 5it [00:00, 122.87it/s, loss=1.99, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2444, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 6it [00:00, 116.25it/s, loss=1.9, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.3715, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 7it [00:00, 114.83it/s, loss=1.82, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2673, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 8it [00:00, 119.55it/s, loss=1, v_num=32]   {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.1217, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 9it [00:00, 117.87it/s, loss=0.914, v_num=32]
# /home/tk/.virtualenvs/explicit-memory/lib/python3.7/site-packages/ipykernel_launcher.py:30: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /home/tk/.virtualenvs/explicit-memory/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:406: LightningDeprecationWarning: One of the returned values {'log', 'progress_bar'} has a `grad_fn`. We will detach it automatically but this behaviour will change in v1.6. Please detach it manually: `return {'loss': ..., 'something': something.detach()}`
#   f"One of the returned values {set(extra.keys())} has a `grad_fn`. We will detach it automatically"
# {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2817, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 10it [00:00, 119.71it/s, loss=0.834, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1872, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 11it [00:00, 118.92it/s, loss=0.674, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 12it [00:00, 120.08it/s, loss=0.592, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2600, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 0it [00:00, 2233.39it/s, loss=0.519, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2521, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 1it [00:00, 295.48it/s, loss=0.489, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.6912, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 2it [00:00, 239.11it/s, loss=0.492, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1497, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 3it [00:00, 189.82it/s, loss=0.441, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0787, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 4it [00:00, 182.10it/s, loss=0.401, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0617, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 5it [00:00, 167.50it/s, loss=0.365, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.4229, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 6it [00:00, 165.46it/s, loss=0.362, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.6344, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 7it [00:00, 165.63it/s, loss=0.34, v_num=32] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.3110, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 8it [00:00, 162.46it/s, loss=0.33, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1078, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 9it [00:00, 161.92it/s, loss=0.299, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 10it [00:00, 159.63it/s, loss=0.288, v_num=32]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0731, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 11it [00:00, 155.47it/s, loss=0.288, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(1, device='cuda:0'), 'train_loss': tensor(0.1374, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 12it [00:00, 151.80it/s, loss=0.288, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.4113, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 0it [00:00, 2109.81it/s, loss=0.296, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1753, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 1it [00:00, 285.39it/s, loss=0.287, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1566, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 2it [00:00, 223.84it/s, loss=0.281, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0578, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 3it [00:00, 197.24it/s, loss=0.228, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1383, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 4it [00:00, 194.11it/s, loss=0.221, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1047, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 5it [00:00, 189.77it/s, loss=0.216, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.3672, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 6it [00:00, 175.44it/s, loss=0.23, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1627, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 7it [00:00, 176.25it/s, loss=0.225, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1252, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 8it [00:00, 174.23it/s, loss=0.219, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0222, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 9it [00:00, 173.97it/s, loss=0.185, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0328, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 10it [00:00, 171.46it/s, loss=0.179, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1083, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 11it [00:00, 168.93it/s, loss=0.181, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1271, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 3: : 12it [00:00, 169.08it/s, loss=0.184, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1735, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 0it [00:00, 1967.31it/s, loss=0.172, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0833, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 1it [00:00, 237.77it/s, loss=0.144, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0497, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 2it [00:00, 169.03it/s, loss=0.131, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 3it [00:00, 171.80it/s, loss=0.126, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0136, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 4it [00:00, 171.99it/s, loss=0.126, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0619, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 5it [00:00, 173.16it/s, loss=0.126, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1184, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 6it [00:00, 174.41it/s, loss=0.125, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0601, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 7it [00:00, 173.61it/s, loss=0.107, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0162, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 8it [00:00, 166.54it/s, loss=0.0992, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 9it [00:00, 166.14it/s, loss=0.0917, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0952, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 10it [00:00, 166.82it/s, loss=0.0936, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0687, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 11it [00:00, 167.36it/s, loss=0.0901, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0503, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 4: : 12it [00:00, 167.86it/s, loss=0.0874, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0199, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 0it [00:00, 2275.80it/s, loss=0.07, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0175, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 1it [00:00, 235.22it/s, loss=0.0628, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0153, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 2it [00:00, 177.69it/s, loss=0.0573, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0234, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 3it [00:00, 152.29it/s, loss=0.0573, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 4it [00:00, 132.35it/s, loss=0.0572, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0257, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 5it [00:00, 119.55it/s, loss=0.053, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0144, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 6it [00:00, 125.77it/s, loss=0.0474, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0280, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 7it [00:00, 130.95it/s, loss=0.0401, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0507, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 8it [00:00, 135.44it/s, loss=0.0385, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0244, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 9it [00:00, 123.74it/s, loss=0.0372, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0086, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 10it [00:00, 127.26it/s, loss=0.0374, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0532, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 11it [00:00, 129.93it/s, loss=0.0394, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 5: : 12it [00:00, 132.33it/s, loss=0.0373, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 0it [00:00, 1610.10it/s, loss=0.0329, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0312, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 1it [00:00, 177.21it/s, loss=0.0314, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0436, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 2it [00:00, 148.70it/s, loss=0.0328, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0111, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 3it [00:00, 139.20it/s, loss=0.033, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0309, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 4it [00:00, 135.74it/s, loss=0.0298, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0202, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 5it [00:00, 133.92it/s, loss=0.0274, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0109, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 6it [00:00, 135.45it/s, loss=0.0254, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 7it [00:00, 138.26it/s, loss=0.0248, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 8it [00:00, 134.56it/s, loss=0.0244, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 9it [00:00, 136.95it/s, loss=0.0238, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0169, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 10it [00:00, 139.10it/s, loss=0.0235, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 11it [00:00, 138.84it/s, loss=0.0226, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 6: : 12it [00:00, 137.32it/s, loss=0.0217, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0102, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 0it [00:00, 1345.19it/s, loss=0.0214, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 1it [00:00, 191.90it/s, loss=0.0205, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 2it [00:00, 170.47it/s, loss=0.0184, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0107, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 3it [00:00, 155.63it/s, loss=0.0177, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 4it [00:00, 146.43it/s, loss=0.0175, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 5it [00:00, 143.32it/s, loss=0.015, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 6it [00:00, 143.36it/s, loss=0.0144, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 7it [00:00, 142.26it/s, loss=0.0131, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 8it [00:00, 139.82it/s, loss=0.0118, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 9it [00:00, 138.15it/s, loss=0.0097, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 10it [00:00, 138.50it/s, loss=0.00927, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 11it [00:00, 137.78it/s, loss=0.00842, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 7: : 12it [00:00, 134.49it/s, loss=0.0077, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 0it [00:00, 1522.99it/s, loss=0.0073, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0106, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 1it [00:00, 260.19it/s, loss=0.00749, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 2it [00:00, 190.99it/s, loss=0.00722, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0176, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 3it [00:00, 166.38it/s, loss=0.00788, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 4it [00:00, 164.06it/s, loss=0.00732, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 5it [00:00, 154.32it/s, loss=0.00686, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 6it [00:00, 147.84it/s, loss=0.00668, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 7it [00:00, 136.79it/s, loss=0.00683, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 8it [00:00, 130.70it/s, loss=0.00669, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 9it [00:00, 125.31it/s, loss=0.00646, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 10it [00:00, 124.50it/s, loss=0.00624, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 11it [00:00, 122.13it/s, loss=0.00616, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 8: : 12it [00:00, 119.43it/s, loss=0.00627, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 0it [00:00, 1217.50it/s, loss=0.00608, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 1it [00:00, 148.09it/s, loss=0.00617, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 2it [00:00, 128.68it/s, loss=0.00641, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 3it [00:00, 124.70it/s, loss=0.00642, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 4it [00:00, 120.18it/s, loss=0.00656, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 5it [00:00, 117.69it/s, loss=0.00631, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0095, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 6it [00:00, 81.09it/s, loss=0.0065, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 7it [00:00, 80.73it/s, loss=0.00675, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 8it [00:00, 81.47it/s, loss=0.00656, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0345, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 9it [00:00, 81.11it/s, loss=0.00808, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 10it [00:00, 82.79it/s, loss=0.00838, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 11it [00:00, 82.21it/s, loss=0.00835, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 9: : 12it [00:00, 81.62it/s, loss=0.00842, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 0it [00:00, 1076.57it/s, loss=0.00889, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0071, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 1it [00:00, 137.59it/s, loss=0.00858, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 2it [00:00, 111.70it/s, loss=0.00861, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 3it [00:00, 103.26it/s, loss=0.00867, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0084, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 4it [00:00, 105.44it/s, loss=0.00878, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 5it [00:00, 105.52it/s, loss=0.00882, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0069, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 6it [00:00, 102.89it/s, loss=0.00894, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 7it [00:00, 103.03it/s, loss=0.00904, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0090, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 8it [00:00, 102.85it/s, loss=0.0092, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 9it [00:00, 103.34it/s, loss=0.009, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 10it [00:00, 103.21it/s, loss=0.00924, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0131, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 11it [00:00, 102.36it/s, loss=0.00963, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 10: : 12it [00:00, 103.09it/s, loss=0.00935, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 0it [00:00, 378.38it/s, loss=0.00905, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0100, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 1it [00:00, 182.63it/s, loss=0.00914, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0085, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 2it [00:00, 150.97it/s, loss=0.00923, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 3it [00:00, 134.64it/s, loss=0.00777, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 4it [00:00, 122.46it/s, loss=0.00669, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 5it [00:00, 109.59it/s, loss=0.00667, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 6it [00:00, 106.64it/s, loss=0.00675, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 7it [00:00, 101.11it/s, loss=0.0064, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0046, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 8it [00:00, 98.79it/s, loss=0.00628, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 9it [00:00, 99.36it/s, loss=0.00612, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 10it [00:00, 97.72it/s, loss=0.00593, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 11it [00:00, 97.99it/s, loss=0.00563, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 11: : 12it [00:00, 98.77it/s, loss=0.00571, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 0it [00:00, 1631.39it/s, loss=0.00559, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 1it [00:00, 203.36it/s, loss=0.00542, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 2it [00:00, 167.00it/s, loss=0.00503, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0081, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 3it [00:00, 144.50it/s, loss=0.00518, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0119, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 4it [00:00, 132.39it/s, loss=0.00541, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0088, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 5it [00:00, 120.79it/s, loss=0.0052, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 6it [00:00, 118.52it/s, loss=0.00519, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 7it [00:00, 116.85it/s, loss=0.0052, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 8it [00:00, 114.68it/s, loss=0.00484, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0039, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 9it [00:00, 112.90it/s, loss=0.00461, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 10it [00:00, 112.38it/s, loss=0.00457, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 11it [00:00, 111.43it/s, loss=0.00463, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 12: : 12it [00:00, 111.01it/s, loss=0.00451, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 0it [00:00, 357.14it/s, loss=0.00435, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 1it [00:00, 165.67it/s, loss=0.00427, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 2it [00:00, 108.32it/s, loss=0.00416, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 3it [00:00, 100.90it/s, loss=0.00414, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 4it [00:00, 96.21it/s, loss=0.0041, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 5it [00:00, 91.55it/s, loss=0.00406, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 6it [00:00, 92.44it/s, loss=0.00392, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 7it [00:00, 94.31it/s, loss=0.00379, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 8it [00:00, 93.36it/s, loss=0.0038, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0103, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 9it [00:00, 93.23it/s, loss=0.00426, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 10it [00:00, 91.93it/s, loss=0.00394, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 11it [00:00, 91.73it/s, loss=0.00353, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 13: : 12it [00:00, 90.45it/s, loss=0.0033, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0155, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 0it [00:00, 1560.38it/s, loss=0.00393, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 1it [00:00, 156.69it/s, loss=0.0038, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 2it [00:00, 128.92it/s, loss=0.00399, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0068, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 3it [00:00, 128.29it/s, loss=0.00413, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 4it [00:00, 111.73it/s, loss=0.00413, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0063, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 5it [00:00, 115.94it/s, loss=0.00429, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 6it [00:00, 117.23it/s, loss=0.00445, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0049, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 7it [00:00, 115.24it/s, loss=0.00456, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 8it [00:00, 114.42it/s, loss=0.00462, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 9it [00:00, 116.65it/s, loss=0.00489, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 10it [00:00, 119.09it/s, loss=0.00495, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 11it [00:00, 119.08it/s, loss=0.00512, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 12it [00:00, 118.59it/s, loss=0.00522, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 0it [00:00, 1730.32it/s, loss=0.00525, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 1it [00:00, 188.16it/s, loss=0.00555, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 2it [00:00, 157.87it/s, loss=0.00572, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 3it [00:00, 160.15it/s, loss=0.00533, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 4it [00:00, 162.60it/s, loss=0.00554, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 5it [00:00, 156.98it/s, loss=0.00557, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 6it [00:00, 158.64it/s, loss=0.00545, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 7it [00:00, 156.88it/s, loss=0.00473, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 8it [00:00, 154.04it/s, loss=0.00487, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 9it [00:00, 154.51it/s, loss=0.00464, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 10it [00:00, 155.27it/s, loss=0.00435, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 11it [00:00, 152.84it/s, loss=0.00421, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 12it [00:00, 153.51it/s, loss=0.00392, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 0it [00:00, 2223.92it/s, loss=0.00379, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 1it [00:00, 253.83it/s, loss=0.00369, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 2it [00:00, 210.68it/s, loss=0.0035, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 3it [00:00, 200.01it/s, loss=0.00328, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 4it [00:00, 181.49it/s, loss=0.0032, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 5it [00:00, 178.55it/s, loss=0.00317, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 6it [00:00, 178.08it/s, loss=0.00316, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 7it [00:00, 170.51it/s, loss=0.00316, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0034, device='cuda:0', grad_fn=<MseLossBackward>)}
# ...
# Epoch 194: : 5it [00:00, 232.37it/s, loss=0.000366, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 6it [00:00, 224.16it/s, loss=0.000362, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 7it [00:00, 219.14it/s, loss=0.00036, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 8it [00:00, 213.25it/s, loss=0.000373, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 9it [00:00, 209.07it/s, loss=0.000382, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 10it [00:00, 207.38it/s, loss=0.000409, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 11it [00:00, 206.20it/s, loss=0.000425, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 12it [00:00, 199.14it/s, loss=0.000419, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 0it [00:00, 2148.72it/s, loss=0.00041, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0117, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 1it [00:00, 226.36it/s, loss=0.000968, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 2it [00:00, 182.39it/s, loss=0.000982, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 3it [00:00, 167.82it/s, loss=0.000962, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 4it [00:00, 164.84it/s, loss=0.000952, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 5it [00:00, 168.12it/s, loss=0.000962, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 6it [00:00, 169.87it/s, loss=0.000982, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 7it [00:00, 171.62it/s, loss=0.00098, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 8it [00:00, 173.76it/s, loss=0.000989, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 9it [00:00, 174.28it/s, loss=0.00101, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 10it [00:00, 173.33it/s, loss=0.00103, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 11it [00:00, 173.26it/s, loss=0.00103, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 12it [00:00, 175.03it/s, loss=0.00102, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 0it [00:00, 2634.61it/s, loss=0.001, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 1it [00:00, 320.22it/s, loss=0.000992, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 2it [00:00, 264.81it/s, loss=0.000991, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 3it [00:00, 241.26it/s, loss=0.000981, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 4it [00:00, 231.20it/s, loss=0.000929, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 5it [00:00, 223.31it/s, loss=0.000905, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 6it [00:00, 207.83it/s, loss=0.000918, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(6.0966e-05, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 7it [00:00, 197.03it/s, loss=0.000901, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(7.0355e-05, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 8it [00:00, 195.70it/s, loss=0.000321, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 9it [00:00, 193.93it/s, loss=0.000315, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(4.6117e-05, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 10it [00:00, 192.47it/s, loss=0.000298, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 11it [00:00, 191.96it/s, loss=0.000294, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 12it [00:00, 191.35it/s, loss=0.000278, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 0it [00:00, 2098.20it/s, loss=0.000263, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 1it [00:00, 308.84it/s, loss=0.000944, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 2it [00:00, 261.80it/s, loss=0.000993, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 3it [00:00, 243.16it/s, loss=0.00101, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 4it [00:00, 232.82it/s, loss=0.001, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 5it [00:00, 227.33it/s, loss=0.00104, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 6it [00:00, 221.39it/s, loss=0.0011, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 7it [00:00, 218.10it/s, loss=0.00112, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 8it [00:00, 214.77it/s, loss=0.00114, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 9it [00:00, 212.43it/s, loss=0.00117, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 10it [00:00, 210.53it/s, loss=0.00122, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 11it [00:00, 210.44it/s, loss=0.00124, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 12it [00:00, 210.45it/s, loss=0.00125, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 0it [00:00, 2557.50it/s, loss=0.00126, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 1it [00:00, 342.08it/s, loss=0.00127, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 2it [00:00, 282.20it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 3it [00:00, 259.83it/s, loss=0.00128, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 4it [00:00, 245.36it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 5it [00:00, 237.11it/s, loss=0.0013, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 6it [00:00, 231.67it/s, loss=0.0013, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 7it [00:00, 225.73it/s, loss=0.0013, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 8it [00:00, 220.05it/s, loss=0.000614, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 9it [00:00, 217.55it/s, loss=0.000582, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 10it [00:00, 215.90it/s, loss=0.00059, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 11it [00:00, 214.96it/s, loss=0.000623, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 12it [00:00, 214.33it/s, loss=0.000594, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 0it [00:00, 2507.06it/s, loss=0.00057, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 1it [00:00, 294.63it/s, loss=0.000571, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0001, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 2it [00:00, 242.65it/s, loss=0.000556, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 3it [00:00, 229.40it/s, loss=0.000516, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0007, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 4it [00:00, 218.36it/s, loss=0.000493, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 5it [00:00, 215.07it/s, loss=0.0013, v_num=32]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 6it [00:00, 212.10it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 7it [00:00, 211.30it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 8it [00:00, 210.16it/s, loss=0.0013, v_num=32] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(8.9217e-05, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 9it [00:00, 209.08it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0002, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 10it [00:00, 208.70it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 11it [00:00, 205.75it/s, loss=0.00129, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(5.2515e-05, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 12it [00:00, 205.71it/s, loss=0.00128, v_num=32]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 13it [00:00, 201.88it/s, loss=0.00128, v_num=32]

# %%
import sys
import os

os.chdir(os.path.join(sys.path[0], ".."))
os.environ["LOGLEVEL"] = "ERROR"

# %%
import numpy as np

from gym.spaces import Space
from gym import logger
from gym.spaces import Box


class MyBox(Space):
    """
    A (possibly unbounded) box in R^n. Specifically, a Box represents the
    Cartesian product of n closed intervals. Each interval has the form of one
    of [a, b], (-oo, b], [a, oo), or (-oo, oo).

    There are two common use cases:

    * Identical bound for each dimension::
        >>> Box(low=-1.0, high=2.0, shape=(3, 4), dtype=np.float32)
        Box(3, 4)

    * Independent bound for each dimension::
        >>> Box(low=np.array([-1.0, -2.0]), high=np.array([2.0, 4.0]), dtype=np.float32)
        Box(2,)

    """

    def __init__(self, low, high, shape=None, dtype=np.float32):
        assert dtype is not None, "dtype must be explicitly provided. "
        self.dtype = np.dtype(dtype)

        # determine shape if it isn't provided directly
        if shape is not None:
            shape = tuple(shape)
            assert (
                np.isscalar(low) or low.shape == shape
            ), "low.shape doesn't match provided shape"
            assert (
                np.isscalar(high) or high.shape == shape
            ), "high.shape doesn't match provided shape"
        elif not np.isscalar(low):
            shape = low.shape
            assert (
                np.isscalar(high) or high.shape == shape
            ), "high.shape doesn't match low.shape"
        elif not np.isscalar(high):
            shape = high.shape
            assert (
                np.isscalar(low) or low.shape == shape
            ), "low.shape doesn't match high.shape"
        else:
            raise ValueError(
                "shape must be provided or inferred from the shapes of low or high"
            )

        if np.isscalar(low):
            low = np.full(shape, low, dtype=dtype)

        if np.isscalar(high):
            high = np.full(shape, high, dtype=dtype)

        self.shape = shape
        self.low = low
        self.high = high

        def _get_precision(dtype):
            if np.issubdtype(dtype, np.floating):
                return np.finfo(dtype).precision
            else:
                return np.inf

        low_precision = _get_precision(self.low.dtype)
        high_precision = _get_precision(self.high.dtype)
        dtype_precision = _get_precision(self.dtype)
        if min(low_precision, high_precision) > dtype_precision:
            logger.warn(
                "Box bound precision lowered by casting to {}".format(self.dtype)
            )
        self.low = self.low.astype(self.dtype)
        self.high = self.high.astype(self.dtype)

        # Boolean arrays which indicate the interval type for each coordinate
        self.bounded_below = -np.inf < self.low
        self.bounded_above = np.inf > self.high

        super().__init__(self.shape, self.dtype)

    def is_bounded(self, manner="both"):
        below = np.all(self.bounded_below)
        above = np.all(self.bounded_above)
        if manner == "both":
            return below and above
        elif manner == "below":
            return below
        elif manner == "above":
            return above
        else:
            raise ValueError("manner is not in {'below', 'above', 'both'}")

    def sample(self):
        """
        Generates a single random sample inside of the Box.

        In creating a sample of the box, each coordinate is sampled according to
        the form of the interval:

        * [a, b] : uniform distribution
        * [a, oo) : shifted exponential distribution
        * (-oo, b] : shifted negative exponential distribution
        * (-oo, oo) : normal distribution
        """
        high = self.high if self.dtype.kind == "f" else self.high.astype("int64") + 1
        sample = np.empty(self.shape)

        # Masking arrays which classify the coordinates according to interval
        # type
        unbounded = ~self.bounded_below & ~self.bounded_above
        upp_bounded = ~self.bounded_below & self.bounded_above
        low_bounded = self.bounded_below & ~self.bounded_above
        bounded = self.bounded_below & self.bounded_above

        # Vectorized sampling by interval type
        sample[unbounded] = self.np_random.normal(size=unbounded[unbounded].shape)

        sample[low_bounded] = (
            self.np_random.exponential(size=low_bounded[low_bounded].shape)
            + self.low[low_bounded]
        )

        sample[upp_bounded] = (
            -self.np_random.exponential(size=upp_bounded[upp_bounded].shape)
            + self.high[upp_bounded]
        )

        sample[bounded] = self.np_random.uniform(
            low=self.low[bounded], high=high[bounded], size=bounded[bounded].shape
        )
        if self.dtype.kind == "i":
            sample = np.floor(sample)

        return sample.astype(self.dtype)

    def contains(self, x):
        if isinstance(x, list):
            x = np.array(x)  # Promote list to array for contains check
        return (
            x.shape == self.shape and np.all(x >= self.low) and np.all(x <= self.high)
        )

    def to_jsonable(self, sample_n):
        return np.array(sample_n).tolist()

    def from_jsonable(self, sample_n):
        return [np.asarray(sample) for sample in sample_n]

    def __repr__(self):
        return "Box({}, {}, {}, {})".format(
            self.low.min(), self.high.max(), self.shape, self.dtype
        )

    def __eq__(self, other):
        return (
            isinstance(other, Box)
            and (self.shape == other.shape)
            and np.allclose(self.low, other.low)
            and np.allclose(self.high, other.high)
        )

# %%
import numpy as np
import gym
from gym import spaces


class GoLeftEnv(gym.Env):
    """
    Custom Environment that follows gym interface.
    This is a simple env where the agent must learn to go always left.
    """

    # Because of google colab, we cannot implement the GUI ('human' render mode)
    metadata = {"render.modes": ["console"]}
    # Define constants for clearer code
    LEFT = 0
    RIGHT = 1

    def __init__(self, grid_size=10):
        super(GoLeftEnv, self).__init__()

        # Size of the 1D-grid
        self.grid_size = grid_size
        # Initialize the agent at the right of the grid
        self.agent_pos = grid_size - 1

        # Define action and observation space
        # They must be gym.spaces objects
        # Example when using discrete actions, we have two: left and right
        n_actions = 2
        self.action_space = spaces.Discrete(n_actions)
        # The observation will be the coordinate of the agent
        # this can be described both by Discrete and Box space
        self.observation_space = MyBox(
            low=0, high=self.grid_size, shape=(1,), dtype=np.float32
        )

    def reset(self):
        """
        Important: the observation must be a numpy array
        :return: (np.array)
        """
        # Initialize the agent at the right of the grid
        self.agent_pos = self.grid_size - 1
        # here we convert to float32 to make it more general (in case we want to use continuous actions)
        return np.array([self.agent_pos]).astype(np.float32)

    def step(self, action):
        if action == self.LEFT:
            self.agent_pos -= 1
        elif action == self.RIGHT:
            self.agent_pos += 1
        else:
            raise ValueError(
                "Received invalid action={} which is not part of the action space".format(
                    action
                )
            )

        # Account for the boundaries of the grid
        self.agent_pos = np.clip(self.agent_pos, 0, self.grid_size)

        # Are we at the left of the grid?
        done = bool(self.agent_pos == 0)

        # Null reward everywhere except when reaching the goal (left of the grid)
        reward = 1 if self.agent_pos == 0 else 0

        # Optionally we can pass additional info, we are not using that for now
        info = {}

        return np.array([self.agent_pos]).astype(np.float32), reward, done, info

    def render(self, mode="console"):
        if mode != "console":
            raise NotImplementedError()
        # agent is represented as a cross, rest as a dot
        print("." * self.agent_pos, end="")
        print("x", end="")
        print("." * (self.grid_size - self.agent_pos))

    def close(self):
        pass

# %%
import os
from collections import OrderedDict, deque, namedtuple
from typing import List, Tuple

import gym
import numpy as np
import torch
from pytorch_lightning import LightningModule, Trainer
from pytorch_lightning.utilities import DistributedType
from torch import Tensor, nn
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader
from torch.utils.data.dataset import IterableDataset

PATH_DATASETS = os.environ.get("PATH_DATASETS", ".")
AVAIL_GPUS = min(1, torch.cuda.device_count())

# %%
class DQN(nn.Module):
    """Simple MLP network."""

    def __init__(self, obs_size: int, n_actions: int, hidden_size: int = 128):
        """
        Args:
            obs_size: observation/state size of the environment
            n_actions: number of discrete actions available in the environment
            hidden_size: size of hidden layers
        """
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
        )

    def forward(self, x):
        return self.net(x.float())

# %%
# Named tuple for storing experience steps gathered in training
Experience = namedtuple(
    "Experience",
    field_names=["state", "action", "reward", "done", "new_state"],
)

# %%
class ReplayBuffer:
    """Replay Buffer for storing past experiences allowing the agent to learn from them.

    Args:
        capacity: size of the buffer
    """

    def __init__(self, capacity: int) -> None:
        self.buffer = deque(maxlen=capacity)

    def __len__(self) -> None:
        return len(self.buffer)

    def append(self, experience: Experience) -> None:
        """Add experience to the buffer.

        Args:
            experience: tuple (state, action, reward, done, new_state)
        """
        self.buffer.append(experience)

    def sample(self, batch_size: int) -> Tuple:
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(
            *(self.buffer[idx] for idx in indices)
        )

        return (
            np.array(states),
            np.array(actions),
            np.array(rewards, dtype=np.float32),
            np.array(dones, dtype=np.bool),
            np.array(next_states),
        )

# %%
class RLDataset(IterableDataset):
    """Iterable Dataset containing the ExperienceBuffer which will be updated with new experiences during training.

    Args:
        buffer: replay buffer
        sample_size: number of experiences to sample at a time
    """

    def __init__(self, buffer: ReplayBuffer, sample_size: int = 200) -> None:
        self.buffer = buffer
        self.sample_size = sample_size

    def __iter__(self) -> Tuple:
        states, actions, rewards, dones, new_states = self.buffer.sample(
            self.sample_size
        )
        for i in range(len(dones)):
            yield states[i], actions[i], rewards[i], dones[i], new_states[i]

# %%
class Agent:
    """Base Agent class handeling the interaction with the environment."""

    def __init__(self, env: gym.Env, replay_buffer: ReplayBuffer) -> None:
        """
        Args:
            env: training environment
            replay_buffer: replay buffer storing experiences
        """
        self.env = env
        self.replay_buffer = replay_buffer
        self.reset()
        self.state = self.env.reset()

    def reset(self) -> None:
        """Resents the environment and updates the state."""
        self.state = self.env.reset()

    def get_action(self, net: nn.Module, epsilon: float, device: str) -> int:
        """Using the given network, decide what action to carry out using an epsilon-greedy policy.

        Args:
            net: DQN network
            epsilon: value to determine likelihood of taking a random action
            device: current device

        Returns:
            action
        """
        if np.random.random() < epsilon:
            action = self.env.action_space.sample()
        else:
            state = torch.tensor([self.state])

            if device not in ["cpu"]:
                state = state.cuda(device)

            q_values = net(state)
            _, action = torch.max(q_values, dim=1)
            action = int(action.item())

        return action

    @torch.no_grad()
    def play_step(
        self,
        net: nn.Module,
        epsilon: float = 0.0,
        device: str = "cpu",
    ) -> Tuple[float, bool]:
        """Carries out a single interaction step between the agent and the environment.

        Args:
            net: DQN network
            epsilon: value to determine likelihood of taking a random action
            device: current device

        Returns:
            reward, done
        """

        action = self.get_action(net, epsilon, device)

        # do step in the environment
        new_state, reward, done, _ = self.env.step(action)

        exp = Experience(self.state, action, reward, done, new_state)

        self.replay_buffer.append(exp)

        self.state = new_state
        if done:
            self.reset()
        return reward, done

# %%
class DQNLightning(LightningModule):
    """Basic DQN Model."""

    def __init__(
        self,
        batch_size: int = 16,
        lr: float = 1e-2,
        env: str = "CartPole-v0",
        gamma: float = 0.99,
        sync_rate: int = 10,
        replay_size: int = 1000,
        warm_start_size: int = 1000,
        eps_last_frame: int = 1000,
        eps_start: float = 1.0,
        eps_end: float = 0.01,
        episode_length: int = 200,
        warm_start_steps: int = 1000,
    ) -> None:
        """
        Args:
            batch_size: size of the batches")
            lr: learning rate
            env: gym environment tag
            gamma: discount factor
            sync_rate: how many frames do we update the target network
            replay_size: capacity of the replay buffer
            warm_start_size: how many samples do we use to fill our buffer at the start of training
            eps_last_frame: what frame should epsilon stop decaying
            eps_start: starting value of epsilon
            eps_end: final value of epsilon
            episode_length: max length of an episode
            warm_start_steps: max episode reward in the environment
        """
        super().__init__()
        self.save_hyperparameters()

        # self.env = gym.make(self.hparams.env)
        self.env = GoLeftEnv()
        obs_size = self.env.observation_space.shape[0]
        n_actions = self.env.action_space.n

        self.net = DQN(obs_size, n_actions)
        self.target_net = DQN(obs_size, n_actions)

        self.buffer = ReplayBuffer(self.hparams.replay_size)
        self.agent = Agent(self.env, self.buffer)
        self.total_reward = 0
        self.episode_reward = 0
        self.populate(self.hparams.warm_start_steps)

    def populate(self, steps: int = 1000) -> None:
        """Carries out several random steps through the environment to initially fill up the replay buffer with
        experiences.

        Args:
            steps: number of random steps to populate the buffer with
        """
        for i in range(steps):
            self.agent.play_step(self.net, epsilon=1.0)

    def forward(self, x: Tensor) -> Tensor:
        """Passes in a state x through the network and gets the q_values of each action as an output.

        Args:
            x: environment state

        Returns:
            q values
        """
        output = self.net(x)
        return output

    def dqn_mse_loss(self, batch: Tuple[Tensor, Tensor]) -> Tensor:
        """Calculates the mse loss using a mini batch from the replay buffer.

        Args:
            batch: current mini batch of replay data

        Returns:
            loss
        """
        states, actions, rewards, dones, next_states = batch

        state_action_values = (
            self.net(states).gather(1, actions.unsqueeze(-1)).squeeze(-1)
        )

        with torch.no_grad():
            next_state_values = self.target_net(next_states).max(1)[0]
            next_state_values[dones] = 0.0
            next_state_values = next_state_values.detach()

        expected_state_action_values = next_state_values * self.hparams.gamma + rewards

        return nn.MSELoss()(state_action_values, expected_state_action_values)

    def training_step(self, batch: Tuple[Tensor, Tensor], nb_batch) -> OrderedDict:
        """Carries out a single step through the environment to update the replay buffer.
        Then calculates loss based on the minibatch recieved.

        Args
        ----
        batch: current mini batch of replay data
        nb_batch: batch number

        Returns
        -------
        Training loss and log metrics

        """
        device = self.get_device(batch)
        epsilon = max(
            self.hparams.eps_end,
            self.hparams.eps_start - self.global_step + 1 / self.hparams.eps_last_frame,
        )

        # step through environment with agent
        reward, done = self.agent.play_step(self.net, epsilon, device)
        self.episode_reward += reward

        # calculates training loss
        loss = self.dqn_mse_loss(batch)

        if self.trainer._distrib_type in {DistributedType.DP, DistributedType.DDP2}:
            loss = loss.unsqueeze(0)

        if done:
            self.total_reward = self.episode_reward
            self.episode_reward = 0

        # Soft update of target network
        if self.global_step % self.hparams.sync_rate == 0:
            self.target_net.load_state_dict(self.net.state_dict())

        log = {
            "total_reward": torch.tensor(self.total_reward).to(device),
            "reward": torch.tensor(reward).to(device),
            "train_loss": loss,
        }
        print(log)
        status = {
            "steps": torch.tensor(self.global_step).to(device),
            "total_reward": torch.tensor(self.total_reward).to(device),
        }

        return OrderedDict({"loss": loss, "log": log, "progress_bar": status})

    def configure_optimizers(self) -> List[Optimizer]:
        """Initialize Adam optimizer."""
        optimizer = Adam(self.net.parameters(), lr=self.hparams.lr)
        return [optimizer]

    def __dataloader(self) -> DataLoader:
        """Initialize the Replay Buffer dataset used for retrieving experiences."""
        dataset = RLDataset(self.buffer, self.hparams.episode_length)
        dataloader = DataLoader(
            dataset=dataset,
            batch_size=self.hparams.batch_size,
        )
        return dataloader

    def train_dataloader(self) -> DataLoader:
        """Get train loader."""
        return self.__dataloader()

    def get_device(self, batch) -> str:
        """Retrieve device currently being used by minibatch."""
        return batch[0].device.index if self.on_gpu else "cpu"

# %%
model = DQNLightning()

trainer = Trainer(
    gpus=AVAIL_GPUS,
    max_epochs=200,
    val_check_interval=100,
)

trainer.fit(model)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name       | Type | Params
# ------------------------------------
# 0 | net        | DQN  | 514
# 1 | target_net | DQN  | 514
# ------------------------------------
# 1.0 K     Trainable params
# 0         Non-trainable params
# 1.0 K     Total params
# 0.004     Total estimated model params size (MB)
# Epoch 0: : 0it [00:00, 2598.70it/s]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.9946, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 1it [00:00, 306.76it/s, loss=1.99, v_num=35]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(8.1937, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 2it [00:00, 262.61it/s, loss=5.09, v_num=35]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(5.4254, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 3it [00:00, 240.56it/s, loss=5.2, v_num=35] {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.3726, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 4it [00:00, 232.08it/s, loss=4, v_num=35]  {'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.8559, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 5it [00:00, 223.21it/s, loss=3.37, v_num=35]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(3.0603, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 6it [00:00, 218.25it/s, loss=3.32, v_num=35]{'total_reward': tensor(0, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(4.5730, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 7it [00:00, 215.16it/s, loss=3.5, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(1, device='cuda:0'), 'train_loss': tensor(2.8767, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 8it [00:00, 204.27it/s, loss=3.42, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.0911, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 9it [00:00, 193.45it/s, loss=3.16, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1158, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 10it [00:00, 187.81it/s, loss=2.86, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.6013, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 11it [00:00, 182.41it/s, loss=2.65, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.5033, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 0: : 12it [00:00, 178.73it/s, loss=2.47, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.7242, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 0it [00:00, 1546.57it/s, loss=2.41, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.4687, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 1it [00:00, 267.65it/s, loss=2.35, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(1.2930, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 2it [00:00, 229.46it/s, loss=2.28, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.7368, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 3it [00:00, 204.47it/s, loss=2.18, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1066, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 4it [00:00, 200.84it/s, loss=2.06, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0578, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 5it [00:00, 187.90it/s, loss=1.95, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.4841, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 6it [00:00, 177.12it/s, loss=1.87, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.8179, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 7it [00:00, 178.45it/s, loss=1.82, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.9768, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 8it [00:00, 176.53it/s, loss=1.77, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0726, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 9it [00:00, 175.05it/s, loss=1.36, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0565, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 10it [00:00, 176.70it/s, loss=1.09, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0840, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 11it [00:00, 174.86it/s, loss=1.08, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0949, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 1: : 12it [00:00, 176.64it/s, loss=1.04, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 0it [00:00, 2394.01it/s, loss=0.892, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0690, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: : 1it [00:00, 292.30it/s, loss=0.667, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 2: :
v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 4it [00:00, 157.49it/s, loss=0.092, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0296, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 5it [00:00, 151.71it/s, loss=0.0911, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0112, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 6it [00:00, 153.64it/s, loss=0.0898, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2330, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 7it [00:00, 155.09it/s, loss=0.0975, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0516, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 8it [00:00, 155.70it/s, loss=0.0983, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1362, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 9it [00:00, 155.66it/s, loss=0.105, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1085, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 10it [00:00, 155.40it/s, loss=0.091, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0485, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 11it [00:00, 154.82it/s, loss=0.0892, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0523, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 14: : 12it [00:00, 150.26it/s, loss=0.0816, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1119, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 0it [00:00, 2138.86it/s, loss=0.0784, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2315, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 1it [00:00, 274.31it/s, loss=0.0887, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 2it [00:00, 208.13it/s, loss=0.0866, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0295, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 3it [00:00, 196.22it/s, loss=0.0857, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2517, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 4it [00:00, 182.04it/s, loss=0.0958, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0377, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 5it [00:00, 173.52it/s, loss=0.0962, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0378, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 6it [00:00, 169.18it/s, loss=0.0967, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0846, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 7it [00:00, 165.51it/s, loss=0.0987, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0458, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 8it [00:00, 161.84it/s, loss=0.101, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0447, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 9it [00:00, 162.01it/s, loss=0.0858, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0782, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 10it [00:00, 160.76it/s, loss=0.085, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2632, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 11it [00:00, 159.97it/s, loss=0.0968, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0401, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 15: : 12it [00:00, 158.67it/s, loss=0.0974, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0713, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 0it [00:00, 2361.66it/s, loss=0.1, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0113, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 1it [00:00, 254.35it/s, loss=0.0893, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2684, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 2it [00:00, 197.19it/s, loss=0.1, v_num=35]   {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2234, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 3it [00:00, 178.94it/s, loss=0.104, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1133, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 4it [00:00, 173.62it/s, loss=0.105, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0511, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 5it [00:00, 160.88it/s, loss=0.105, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0128, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 6it [00:00, 157.01it/s, loss=0.103, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.2467, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 7it [00:00, 154.76it/s, loss=0.11, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0452, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 8it [00:00, 155.00it/s, loss=0.1, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.1821, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 9it [00:00, 151.64it/s, loss=0.107, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0527, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 16: : 10it [00:00, 152.04it/s, loss=0.108, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0588, device='cuda:0', grad_fn=<MseLossBackward>)}
# ...
# Epoch 194: : 5it [00:00, 268.56it/s, loss=0.00253, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 6it [00:00, 261.77it/s, loss=0.00251, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 7it [00:00, 219.10it/s, loss=0.00244, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 8it [00:00, 220.03it/s, loss=0.00241, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 9it [00:00, 221.62it/s, loss=0.00269, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 10it [00:00, 222.79it/s, loss=0.00257, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 11it [00:00, 223.98it/s, loss=0.00269, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 194: : 12it [00:00, 224.47it/s, loss=0.00285, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 0it [00:00, 3004.52it/s, loss=0.00275, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 1it [00:00, 395.11it/s, loss=0.00282, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 2it [00:00, 321.59it/s, loss=0.00287, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 3it [00:00, 293.64it/s, loss=0.00264, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 4it [00:00, 279.73it/s, loss=0.00279, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 5it [00:00, 271.17it/s, loss=0.00272, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 6it [00:00, 251.74it/s, loss=0.00281, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 7it [00:00, 238.82it/s, loss=0.00281, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 8it [00:00, 236.32it/s, loss=0.00281, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 9it [00:00, 236.31it/s, loss=0.00269, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 10it [00:00, 235.51it/s, loss=0.0028, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 11it [00:00, 234.80it/s, loss=0.0027, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 195: : 12it [00:00, 235.18it/s, loss=0.0027, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 0it [00:00, 2709.50it/s, loss=0.00277, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 1it [00:00, 385.05it/s, loss=0.0026, v_num=35]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 2it [00:00, 308.59it/s, loss=0.00262, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0093, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 3it [00:00, 279.38it/s, loss=0.00268, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 4it [00:00, 265.75it/s, loss=0.00298, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0126, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 5it [00:00, 258.26it/s, loss=0.00339, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0099, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 6it [00:00, 246.65it/s, loss=0.00368, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0065, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 7it [00:00, 235.92it/s, loss=0.00397, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0135, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 8it [00:00, 229.67it/s, loss=0.00446, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 9it [00:00, 226.48it/s, loss=0.00461, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 10it [00:00, 223.31it/s, loss=0.00484, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0156, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 11it [00:00, 220.55it/s, loss=0.0054, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 196: : 12it [00:00, 218.67it/s, loss=0.00579, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 0it [00:00, 2318.58it/s, loss=0.00593, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0167, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 1it [00:00, 303.84it/s, loss=0.00662, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 2it [00:00, 256.33it/s, loss=0.00667, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 3it [00:00, 212.83it/s, loss=0.00703, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 4it [00:00, 189.29it/s, loss=0.00724, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0040, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 5it [00:00, 177.42it/s, loss=0.00743, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 6it [00:00, 173.00it/s, loss=0.00779, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 7it [00:00, 153.31it/s, loss=0.00765, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0077, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 8it [00:00, 157.24it/s, loss=0.008, v_num=35]  {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 9it [00:00, 160.32it/s, loss=0.00807, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 10it [00:00, 163.23it/s, loss=0.00789, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0003, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 11it [00:00, 164.03it/s, loss=0.00758, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0044, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 197: : 12it [00:00, 164.81it/s, loss=0.00717, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 0it [00:00, 1776.49it/s, loss=0.00697, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 1it [00:00, 241.98it/s, loss=0.00667, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0056, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 2it [00:00, 185.02it/s, loss=0.00627, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0067, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 3it [00:00, 172.46it/s, loss=0.00634, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 4it [00:00, 168.35it/s, loss=0.00612, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0125, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 5it [00:00, 164.54it/s, loss=0.00596, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 6it [00:00, 159.76it/s, loss=0.00557, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 7it [00:00, 154.35it/s, loss=0.00544, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 8it [00:00, 155.90it/s, loss=0.00487, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 9it [00:00, 152.93it/s, loss=0.00478, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 10it [00:00, 154.21it/s, loss=0.00436, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 11it [00:00, 153.11it/s, loss=0.00409, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 198: : 12it [00:00, 150.87it/s, loss=0.00398, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 0it [00:00, 2088.80it/s, loss=0.00356, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 1it [00:00, 242.87it/s, loss=0.00368, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 2it [00:00, 185.57it/s, loss=0.00332, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 3it [00:00, 181.00it/s, loss=0.0032, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 4it [00:00, 163.60it/s, loss=0.00302, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 5it [00:00, 160.89it/s, loss=0.00304, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 6it [00:00, 161.82it/s, loss=0.00287, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 7it [00:00, 156.19it/s, loss=0.00266, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0005, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 8it [00:00, 156.37it/s, loss=0.00266, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 9it [00:00, 154.48it/s, loss=0.00248, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 10it [00:00, 156.15it/s, loss=0.00221, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 11it [00:00, 151.20it/s, loss=0.00219, v_num=35]{'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 12it [00:00, 152.04it/s, loss=0.0017, v_num=35] {'total_reward': tensor(1, device='cuda:0'), 'reward': tensor(0, device='cuda:0'), 'train_loss': tensor(0.0004, device='cuda:0', grad_fn=<MseLossBackward>)}
# Epoch 199: : 13it [00:00, 147.07it/s, loss=0.00168, v_num=35]
